# %%
import importlib
import search
importlib.reload(search)
# Out:
# <module 'search' from '/Users/tianalongjam/Downloads/School🏫/Coding/projects/new-search-engine-with-exa-ai/search.py'>

# %%
qsearch = search.BiasDiversityCheck(query="AI Ethics")
qsearch
# Out:
# The query you provided is AI Ethics for 50 results

# %%
df = qsearch.get_responses()

# %%
qsearch.find_dominant_domain()
# Out:
# 'No particular domain dominates your search results'

# %%
qsearch.find_hhi()
# Out:
# 'The computed HHI for this query indicates an unconcentrated distribution of sources. No single domain dominates the search results, suggesting a diverse set of perspectives.'

# %%
qsearch.find_shannon_entropy()
# Out:
# 'The normalized entropy for this query is in the high range, meaning the results are well-distributed across many domains. No single source dominates, suggesting a broad and balanced range of perspectives in the retrieved information.'

# %%
qsearch.find_gini()
# Out:
# 'The Gini coefficient for this query falls in the low range, suggesting that the results are fairly evenly distributed across domains. No single source dominates, and the overall diversity of perspectives is strong.'

# %%
qsearch.sentiment_analysis()
# Out:
# Device set to use mps:0
#                                                 Title Snippet  Sentiment
# 0   AI Ethics: What It Is, Why It Matters, and Mor...    None   0.918349
# 1                            What is AI Ethics? | IBM    None  -0.994391
# 2   The Pentagon’s AI Ethics Push: Keeping Machine...    None  -0.897151
# 3          Ethics of Artificial Intelligence | UNESCO    None  -0.956915
# 4   AI and the Ethics of Decision-Making in Law an...    None   0.978718
# 5       Ethics of artificial intelligence - Wikipedia    None  -0.990360
# 6                                    The ethics of AI    None  -0.904324
# 7   Addressing equity and ethics in artificial int...    None   0.996145
# 8                                        Ethics of AI    None  -0.845922
# 9                      AI Ethics: Global Perspectives    None   0.860292
# 10  AI Ethics: What It Is, Why It Matters, and Mor...    None   0.918349
# 11                           What is AI Ethics? | IBM    None  -0.994391
# 12  The Pentagon’s AI Ethics Push: Keeping Machine...    None  -0.897151
# 13         Ethics of Artificial Intelligence | UNESCO    None  -0.956915
# 14  AI and the Ethics of Decision-Making in Law an...    None   0.978718
# 15      Ethics of artificial intelligence - Wikipedia    None  -0.990360
# 16                                   The ethics of AI    None  -0.904324
# 17  Addressing equity and ethics in artificial int...    None   0.996145
# 18                                       Ethics of AI    None  -0.845922
# 19                     AI Ethics: Global Perspectives    None   0.860292
# 20  AI Ethics: What It Is, Why It Matters, and Mor...    None   0.918349
# 21                           What is AI Ethics? | IBM    None  -0.994391
# 22  The Pentagon’s AI Ethics Push: Keeping Machine...    None  -0.897151
# 23         Ethics of Artificial Intelligence | UNESCO    None  -0.956915
# 24  AI and the Ethics of Decision-Making in Law an...    None   0.978718
# 25      Ethics of artificial intelligence - Wikipedia    None  -0.990360
# 26                                   The ethics of AI    None  -0.904324
# 27  Addressing equity and ethics in artificial int...    None   0.996145
# 28                                       Ethics of AI    None  -0.845922
# 29                     AI Ethics: Global Perspectives    None   0.860292
# 30  AI Ethics: What It Is, Why It Matters, and Mor...    None   0.918349
# 31                           What is AI Ethics? | IBM    None  -0.994391
# 32  The Pentagon’s AI Ethics Push: Keeping Machine...    None  -0.897151
# 33         Ethics of Artificial Intelligence | UNESCO    None  -0.956915
# 34  AI and the Ethics of Decision-Making in Law an...    None   0.978718
# 35      Ethics of artificial intelligence - Wikipedia    None  -0.990360
# 36                                   The ethics of AI    None  -0.904324
# 37  Addressing equity and ethics in artificial int...    None   0.996145
# 38                                       Ethics of AI    None  -0.845922
# 39                     AI Ethics: Global Perspectives    None   0.860292
# 40  AI Ethics: What It Is, Why It Matters, and Mor...    None   0.918349
# 41                           What is AI Ethics? | IBM    None  -0.994391
# 42  The Pentagon’s AI Ethics Push: Keeping Machine...    None  -0.897151
# 43         Ethics of Artificial Intelligence | UNESCO    None  -0.956915
# 44  AI and the Ethics of Decision-Making in Law an...    None   0.978718
# 45      Ethics of artificial intelligence - Wikipedia    None  -0.990360
# 46                                   The ethics of AI    None  -0.904324
# 47  Addressing equity and ethics in artificial int...    None   0.996145
# 48                                       Ethics of AI    None  -0.845922
# 49  Artificial Intelligence Ethics Framework for t...    None   0.920191

# %%
qsearch.visualize()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 qsearch.visualize()
#
# AttributeError: 'BiasDiversityCheck' object has no attribute 'visualize'
